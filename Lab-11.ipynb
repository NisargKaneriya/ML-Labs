# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
# Name:Nisarg Kaneriya
# Enrollnment no. : 22010101086
#
# <center><b><h1>Lab - 11 </b></center>
# <pre>

# %% [markdown]
# ## Step 1: Import Necessary Libraries
# complete the import statements below.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler  
from sklearn.datasets import load_iris  
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# PCA & LDA
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %% [markdown]
# ## Step 2: Load the Dataset
# Load the dataset (e.g., Iris dataset) or use your own.

# %%
df = load_iris()
x = df.data
y = df.target

# %% [markdown]
# ## Step 3: Preprocess the Data (Standardization)
# Standardize the dataset before applying PCA or LDA.

# %%
scaler = StandardScaler() 
x_standard = scaler.fit_transform(x)

# %% [markdown]
# ## Step 4: Apply PCA
# Perform PCA and extract the principal components.

# %%
pca = PCA(n_components=2)  
x_pca = pca.fit_transform(x_standard)

# %%
x_pca
# Out:
# array([[-2.26470281,  0.4800266 ],
#        [-2.08096115, -0.67413356],
#        [-2.36422905, -0.34190802],
#        [-2.29938422, -0.59739451],
#        [-2.38984217,  0.64683538],
#        [-2.07563095,  1.48917752],
#        [-2.44402884,  0.0476442 ],
#        [-2.23284716,  0.22314807],
#        [-2.33464048, -1.11532768],
#        [-2.18432817, -0.46901356],
#        [-2.1663101 ,  1.04369065],
#        [-2.32613087,  0.13307834],
#        [-2.2184509 , -0.72867617],
#        [-2.6331007 , -0.96150673],
#        [-2.1987406 ,  1.86005711],
#        [-2.26221453,  2.68628449],
#        [-2.2075877 ,  1.48360936],
#        [-2.19034951,  0.48883832],
#        [-1.898572  ,  1.40501879],
#        [-2.34336905,  1.12784938],
#        [-1.914323  ,  0.40885571],
#        [-2.20701284,  0.92412143],
#        [-2.7743447 ,  0.45834367],
#        [-1.81866953,  0.08555853],
#        [-2.22716331,  0.13725446],
#        [-1.95184633, -0.62561859],
#        [-2.05115137,  0.24216355],
# ...

# %% [markdown]
# ## Step 5: Apply LDA
# Perform LDA and extract the discriminant components.

# %%
lda = LDA(n_components=2) 
x_lda = lda.fit_transform(x_standard, y)

# %%
x_lda
# Out:
# array([[ 8.06179978e+00,  3.00420621e-01],
#        [ 7.12868772e+00, -7.86660426e-01],
#        [ 7.48982797e+00, -2.65384488e-01],
#        [ 6.81320057e+00, -6.70631068e-01],
#        [ 8.13230933e+00,  5.14462530e-01],
#        [ 7.70194674e+00,  1.46172097e+00],
#        [ 7.21261762e+00,  3.55836209e-01],
#        [ 7.60529355e+00, -1.16338380e-02],
#        [ 6.56055159e+00, -1.01516362e+00],
#        [ 7.34305989e+00, -9.47319209e-01],
#        [ 8.39738652e+00,  6.47363392e-01],
#        [ 7.21929685e+00, -1.09646389e-01],
#        [ 7.32679599e+00, -1.07298943e+00],
#        [ 7.57247066e+00, -8.05464137e-01],
#        [ 9.84984300e+00,  1.58593698e+00],
#        [ 9.15823890e+00,  2.73759647e+00],
#        [ 8.58243141e+00,  1.83448945e+00],
#        [ 7.78075375e+00,  5.84339407e-01],
#        [ 8.07835876e+00,  9.68580703e-01],
#        [ 8.02097451e+00,  1.14050366e+00],
#        [ 7.49680227e+00, -1.88377220e-01],
#        [ 7.58648117e+00,  1.20797032e+00],
# ...

# %% [markdown]
# ## Step 6: Visualization
# Visualize PCA and LDA results using scatter plots.

# %%
# PCA visualization

scatter = plt.scatter(x_pca[:, 0], x_pca[:, 1], c=y, cmap='jet', edgecolor='b', alpha=0.7)
plt.title("PCA Visualization of the Iris Dataset")
plt.grid(True)
plt.show()

# %%
# LDA visualization

scatter = plt.scatter(x_lda[:, 0], x_lda[:, 1], c=y, cmap='jet', edgecolor='b', alpha=0.7)
plt.title("LDA Visualization of the Iris Dataset")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Train the model using above data

# %%
# Using PCA

xp_train,xp_test,yp_train,yp_test = train_test_split(x_pca,y,test_size=0.3,random_state=123)
model = DecisionTreeClassifier()
model.fit(xp_train,yp_train)
yp_pred = model.predict(xp_test)

accuracy_score(yp_test,yp_pred)
# Out:
# 0.9333333333333333

# %%
# Using LDA

xl_train,xl_test,yl_train,yl_test = train_test_split(x_lda,y,test_size=0.3,random_state=123)
model = DecisionTreeClassifier()
model.fit(xl_train,yl_train)
yl_pred = model.predict(xl_test)

accuracy_score(yl_test,yl_pred)
# Out:
# 0.9777777777777777

# %% [markdown]
# ## Step 7: Feature Selection using Filter Methods
# In this section, you will apply different filter methods such as:
# - **Pearson Correlation Coefficient**
# - **Chi-Square Test**
# - **Variance Thresholding**

# %% [markdown]
# ### 8.1 Pearson Correlation Coefficient
# Calculate the correlation between features and the target variable.

# %%
import seaborn as sns


correlation_matrix = np.corrcoef(x_standard.T)
sns.heatmap(correlation_matrix, annot=True)
plt.title('Pearson Correlation Coefficient')
plt.show()
# Out:
# array([[-9.00681170e-01, -1.14301691e+00, -1.38535265e+00,
#         -1.50652052e+00, -1.02184904e+00, -5.37177559e-01,
#         -1.50652052e+00, -1.02184904e+00, -1.74885626e+00,
#         -1.14301691e+00, -5.37177559e-01, -1.26418478e+00,
#         -1.26418478e+00, -1.87002413e+00, -5.25060772e-02,
#         -1.73673948e-01, -5.37177559e-01, -9.00681170e-01,
#         -1.73673948e-01, -9.00681170e-01, -5.37177559e-01,
#         -9.00681170e-01, -1.50652052e+00, -9.00681170e-01,
#         -1.26418478e+00, -1.02184904e+00, -1.02184904e+00,
#         -7.79513300e-01, -7.79513300e-01, -1.38535265e+00,
#         -1.26418478e+00, -5.37177559e-01, -7.79513300e-01,
#         -4.16009689e-01, -1.14301691e+00, -1.02184904e+00,
#         -4.16009689e-01, -1.14301691e+00, -1.74885626e+00,
#         -9.00681170e-01, -1.02184904e+00, -1.62768839e+00,
#         -1.74885626e+00, -1.02184904e+00, -9.00681170e-01,
#         -1.26418478e+00, -9.00681170e-01, -1.50652052e+00,
# ...

# %% [markdown]
# ### 8.2 Chi-Square Test
# Use the Chi-Square test to determine the relationship between features and the target variable.

# %%
from sklearn.feature_selection import chi2,SelectKBest

feture_names = df.feature_names

selector = SelectKBest(score_func=chi2)
x_chi = selector.fit_transform(x,y)

chi_score = pd.DataFrame({'Feture':feture_names,'Chi2 Score':selector.scores_})
print(chi_score.sort_values(by="Chi2 Score",ascending=False))
# Out:
#               Feture  Chi2 Score
# 2  petal length (cm)  116.312613
# 3   petal width (cm)   67.048360
# 0  sepal length (cm)   10.817821
# 1   sepal width (cm)    3.710728
# C:\Users\devpa\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=10 is greater than n_features=4. All the features will be returned.
#   warnings.warn(

# %% [markdown]
# ### 8.3 Variance Thresholding
# Remove features with low variance as they may not be useful for predictions.

# %%
from sklearn.feature_selection import VarianceThreshold

variance = VarianceThreshold(threshold=0.2)
x_variance = variance.fit_transform(x_standard)
x_variance.shape
# Out:
# (150, 4)

# %% [markdown]
# ## Step 9: Feature Selection using Wrapper Methods
# Wrapper methods evaluate feature subsets based on model performance.
# In this section, we will use:
# - **Recursive Feature Elimination (RFE)**
# - **Sequential Feature Selection (SFS)**

# %% [markdown]
# ### 9.1 Recursive Feature Elimination (RFE)
# RFE removes the least important features iteratively until the optimal subset is reached.

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
rfe = RFE(model,n_features_to_select=2)
x_rfe = rfe.fit_transform(x_standard,y)

x_rfe.shape
# Out:
# (150, 2)

# %% [markdown]
# ### 9.2 Sequential Feature Selection (SFS)
# SFS iteratively selects the best-performing features by adding or removing them.

# %%
from sklearn.feature_selection import SequentialFeatureSelector

sfs = SequentialFeatureSelector(model, n_features_to_select=2, direction='forward')
x_sfs = sfs.fit_transform(x_standard, y)
x_sfs.shape
# Out:
# (150, 2)

# %% [markdown]
# ## Step 10: Applying PCA on Digits Dataset
# In this section, we will apply PCA on the `load_digits` dataset, which consists of handwritten digit images, and visualize its effect.

# %% [markdown]
# ### 10.1 Load and Visualize the Digits Dataset
# We will load the dataset and visualize some sample images.

# %%
from sklearn.datasets import load_digits

df = load_digits()
x = df.data
y = df.target

scaler = StandardScaler() 
x_standard = scaler.fit_transform(x)
x_standard
# Out:
# array([[ 0.        , -0.33501649, -0.04308102, ..., -1.14664746,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  0.54856067,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  1.56568555,
#          1.6951369 , -0.19600752],
#        ...,
#        [ 0.        , -0.33501649, -0.88456568, ..., -0.12952258,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -0.67419451, ...,  0.8876023 ,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649,  1.00877481, ...,  0.8876023 ,
#         -0.26113572, -0.19600752]])

# %% [markdown]
# ### 10.2 Apply PCA and Reduce Dimensions
# We will reduce the dataset to 2 principal components and visualize the transformed data.

# %%
pca = PCA(n_components=2)  
x_pca = pca.fit_transform(x_standard)
x_pca
# Out:
# array([[-1.91421366, -0.95450157],
#        [-0.58898033,  0.9246358 ],
#        [-1.30203906, -0.31718883],
#        ...,
#        [-1.02259599, -0.14791087],
#        [-1.07605522, -0.38090625],
#        [ 1.25770233, -2.22759088]])

# %%
scatter = plt.scatter(x_pca[:, 0], x_pca[:, 1], c=y, cmap='jet', edgecolor='b', alpha=0.7)
plt.title("PCA Visualization of the Iris Dataset")
plt.grid(True)
plt.show()

# %%
# Using PCA

xp_train,xp_test,yp_train,yp_test = train_test_split(x_pca,y,test_size=0.3,random_state=123)
model = DecisionTreeClassifier()
model.fit(xp_train,yp_train)
yp_pred = model.predict(xp_test)

accuracy_score(yp_test,yp_pred)
# Out:
# 0.5074074074074074
